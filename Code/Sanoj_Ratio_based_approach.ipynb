# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the dataset

# %%
df= pd.read_csv(r"C:\Users\sanoj\Downloads\dynamic_pricing (1).csv")
df.head()
# Out:
#    Number_of_Riders  Number_of_Drivers Location_Category  \
# 0                90                 45             Urban
# 1                58                 39          Suburban
# 2                42                 31             Rural
# 3                89                 28             Rural
# 4                78                 22             Rural
#
#   Customer_Loyalty_Status  Number_of_Past_Rides  Average_Ratings  \
# 0                  Silver                    13             4.47
# 1                  Silver                    72             4.06
# 2                  Silver                     0             3.99
# 3                 Regular                    67             4.31
# 4                 Regular                    74             3.77
#
#   Time_of_Booking Vehicle_Type  Expected_Ride_Duration  \
# 0           Night      Premium                      90
# 1         Evening      Economy                      43
# 2       Afternoon      Premium                      76
# 3       Afternoon      Premium                     134
# 4       Afternoon      Economy                     149
#
#    Historical_Cost_of_Ride
# 0               284.257273
# 1               173.874753
# 2               329.795469
# 3               470.201232
# 4               579.681422

# %%
df.describe()
# Out:
#        Number_of_Riders  Number_of_Drivers  Number_of_Past_Rides  \
# count       1000.000000        1000.000000           1000.000000
# mean          60.372000          27.076000             50.031000
# std           23.701506          19.068346             29.313774
# min           20.000000           5.000000              0.000000
# 25%           40.000000          11.000000             25.000000
# 50%           60.000000          22.000000             51.000000
# 75%           81.000000          38.000000             75.000000
# max          100.000000          89.000000            100.000000
#
#        Average_Ratings  Expected_Ride_Duration  Historical_Cost_of_Ride
# count      1000.000000              1000.00000              1000.000000
# mean          4.257220                99.58800               372.502623
# std           0.435781                49.16545               187.158756
# min           3.500000                10.00000                25.993449
# 25%           3.870000                59.75000               221.365202
# 50%           4.270000               102.00000               362.019426
# 75%           4.632500               143.00000               510.497504
# max           5.000000               180.00000               836.116419

# %% [markdown]
# # Ratio Based Approach

# %% [markdown]
# ## Calculating Demand_Supply_Ratio and picking demand_supply_threshold = 2.3 arround the mean of Demand_Supply_Ratio
# * ### Higher Demand = when 'Demand_Supply_Ratio' > demand_supply_threshold (2.3) else Low-demand
# * ### Higher supply = when 'Demand_Supply_Ratio' < demand_supply_threshold (2.3) else Low-supply

# %%
df['Demand_Supply_Ratio'] = df['Number_of_Riders'] / df['Number_of_Drivers']
demand_supply_threshold = 2.3

df['Demand_class'] = np.where(df['Demand_Supply_Ratio'] > demand_supply_threshold, "Higher_demand", "Lower_demand")
df['Supply_class'] = np.where(df['Demand_Supply_Ratio'] < demand_supply_threshold, "Higher_supply", "Lower_supply")

df.iloc[:,[0,1,10,11,12]].sample(10)
# Out:
#      Number_of_Riders  Number_of_Drivers  Demand_Supply_Ratio   Demand_class  \
# 214                49                 30             1.633333   Lower_demand
# 592                33                 20             1.650000   Lower_demand
# 751                47                 24             1.958333   Lower_demand
# 610                97                  9            10.777778  Higher_demand
# 952                26                  5             5.200000  Higher_demand
# 340                86                 10             8.600000  Higher_demand
# 845                68                 16             4.250000  Higher_demand
# 420                40                 30             1.333333   Lower_demand
# 652                55                 29             1.896552   Lower_demand
# 156                94                 59             1.593220   Lower_demand
#
#       Supply_class
# 214  Higher_supply
# 592  Higher_supply
# 751  Higher_supply
# 610   Lower_supply
# 952   Lower_supply
# 340   Lower_supply
# 845   Lower_supply
# 420  Higher_supply
# 652  Higher_supply
# 156  Higher_supply

# %% [markdown]
# ## calulation Base Price and Surge_charge based on supply demand ratio and demand_supply_factor
# * ### 1. Calculate base historical cost based on expected_Ride_duration
# * ### 2. Calculate rider-to-driver ratio
# * ### 3. Calculate demand-supply factor
# * ### 4. Defining a methode to Calculate supply_demand_surge and Apply the dynamic pricing formula

# %%
constant_rate = 3.5  # Define the base rate per unit of duration, this is arround mean of ratio of ('Historical_Cost_of_Ride'/'Expected_Ride_Duration')
demand_hike = 0.35  # This is how much demand increase the pricing

# Calculate base historical cost based on expected_Ride_duration
df['base_cost'] = df['Expected_Ride_Duration'] * constant_rate

# Calculate rider-to-driver ratio
df['rider_driver_ratio'] = df['Number_of_Riders'] / df['Number_of_Drivers']

# Calculate demand-supply factor
df['demand_supply_factor'] = df['rider_driver_ratio'] - 1
df['demand_supply_factor'] = df['demand_supply_factor'].apply(lambda x: min(x, 6))

# defining a methode to Calculate supply_demand_surge and Apply the dynamic pricing formula
def apply_surge(df):
    SD_surge_charge=0
    if (df['Demand_class']=='Higher_demand') & (df['Supply_class']=='Lower_supply'):
        SD_surge_charge = df['base_cost'] * (demand_hike * df['demand_supply_factor'])
    return SD_surge_charge

df['S/D_surge_charge'] = df.apply(apply_surge,axis=1)
df.head()
# Out:
#    Number_of_Riders  Number_of_Drivers Location_Category  \
# 0                90                 45             Urban
# 1                58                 39          Suburban
# 2                42                 31             Rural
# 3                89                 28             Rural
# 4                78                 22             Rural
#
#   Customer_Loyalty_Status  Number_of_Past_Rides  Average_Ratings  \
# 0                  Silver                    13             4.47
# 1                  Silver                    72             4.06
# 2                  Silver                     0             3.99
# 3                 Regular                    67             4.31
# 4                 Regular                    74             3.77
#
#   Time_of_Booking Vehicle_Type  Expected_Ride_Duration  \
# 0           Night      Premium                      90
# 1         Evening      Economy                      43
# 2       Afternoon      Premium                      76
# 3       Afternoon      Premium                     134
# 4       Afternoon      Economy                     149
#
#    Historical_Cost_of_Ride  Demand_Supply_Ratio   Demand_class   Supply_class  \
# 0               284.257273             2.000000   Lower_demand  Higher_supply
# 1               173.874753             1.487179   Lower_demand  Higher_supply
# 2               329.795469             1.354839   Lower_demand  Higher_supply
# 3               470.201232             3.178571  Higher_demand   Lower_supply
# 4               579.681422             3.545455  Higher_demand   Lower_supply
#
#    base_cost  rider_driver_ratio  demand_supply_factor  S/D_surge_charge
# 0      315.0            2.000000              1.000000          0.000000
# 1      150.5            1.487179              0.487179          0.000000
# 2      266.0            1.354839              0.354839          0.000000
# 3      469.0            3.178571              2.178571        357.612500
# 4      521.5            3.545455              2.545455        464.609091

# %% [markdown]
# ## Conditional Surge based on Vehical_Type and Time_of_booking && Location_Category Condition

# %%
def cal_surge_charge(df):
    surge_charge = 0
    if df['Vehicle_Type'] == 'Premium':
        if (df['Location_Category'] in ('Urban', 'Suburban')) & (df['Time_of_Booking'] in ('Evening', 'Night')):
            surge_charge = df['base_cost'] * 0.05 + df['base_cost'] * 0.02
    else:
        if (df['Location_Category'] in ('Urban', 'Suburban')) & (df['Time_of_Booking'] in ('Evening', 'Night')):
            surge_charge = df['base_cost'] * 0.025 + df['base_cost'] * 0.01
    return surge_charge

df['Surge_charge'] = df.apply(cal_surge_charge, axis=1)

# %%
df.sample(10)
# Out:
#      Number_of_Riders  Number_of_Drivers Location_Category  \
# 894                49                 29          Suburban
# 739                32                  6             Rural
# 497                64                  7          Suburban
# 284                93                 67             Urban
# 367                86                 20          Suburban
# 925                73                 27             Urban
# 846                38                 22             Urban
# 452                57                 46             Rural
# 193                61                 26             Rural
# 179                48                 17          Suburban
#
#     Customer_Loyalty_Status  Number_of_Past_Rides  Average_Ratings  \
# 894                 Regular                    35             4.80
# 739                    Gold                    75             4.47
# 497                 Regular                    92             4.58
# 284                  Silver                    21             4.88
# 367                  Silver                    51             3.75
# 925                 Regular                    55             4.27
# 846                    Gold                    60             3.60
# 452                 Regular                    42             4.39
# 193                    Gold                    21             3.85
# 179                  Silver                     2             4.09
#
#     Time_of_Booking Vehicle_Type  Expected_Ride_Duration  \
# 894         Evening      Premium                     160
# 739         Morning      Premium                     154
# 497         Evening      Premium                      16
# 284           Night      Premium                      87
# 367         Morning      Premium                     110
# 925         Morning      Premium                      50
# 846         Morning      Premium                     104
# 452         Morning      Economy                      56
# 193         Morning      Premium                     126
# 179         Evening      Economy                      85
#
#      Historical_Cost_of_Ride  Demand_Supply_Ratio   Demand_class  \
# 894               468.306920             1.689655   Lower_demand
# 739               721.721269             5.333333  Higher_demand
# 497               114.699202             9.142857  Higher_demand
# 284               417.913141             1.388060   Lower_demand
# 367               412.257463             4.300000  Higher_demand
# 925               216.060196             2.703704  Higher_demand
# 846               312.173159             1.727273   Lower_demand
# 452               210.631767             1.239130   Lower_demand
# 193               604.273047             2.346154  Higher_demand
# 179               261.943533             2.823529  Higher_demand
#
#       Supply_class  base_cost  rider_driver_ratio  demand_supply_factor  \
# 894  Higher_supply      560.0            1.689655              0.689655
# 739   Lower_supply      539.0            5.333333              4.333333
# 497   Lower_supply       56.0            9.142857              6.000000
# 284  Higher_supply      304.5            1.388060              0.388060
# 367   Lower_supply      385.0            4.300000              3.300000
# 925   Lower_supply      175.0            2.703704              1.703704
# 846  Higher_supply      364.0            1.727273              0.727273
# 452  Higher_supply      196.0            1.239130              0.239130
# 193   Lower_supply      441.0            2.346154              1.346154
# 179   Lower_supply      297.5            2.823529              1.823529
#
#      S/D_surge_charge  Surge_charge
# 894          0.000000       39.2000
# 739        817.483333        0.0000
# 497        117.600000        3.9200
# 284          0.000000       21.3150
# 367        444.675000        0.0000
# 925        104.351852        0.0000
# 846          0.000000        0.0000
# 452          0.000000        0.0000
# 193        207.778846        0.0000
# 179        189.875000       10.4125

# %% [markdown]
# ## Calculating Total cost

# %%
df['New_cost']= df['base_cost'] + df['S/D_surge_charge'] + df['Surge_charge']
df.iloc[:,[0,1,9,10,11,12,13,16,17,18]].sample(10)
# Out:
#      Number_of_Riders  Number_of_Drivers  Historical_Cost_of_Ride  \
# 534                55                 23               654.676536
# 80                 42                 22               366.151526
# 925                73                 27               216.060196
# 67                 76                 40                96.035209
# 708                50                 40               319.110983
# 415                94                 27               547.981462
# 133                85                 36               506.692886
# 309                42                  8               599.716253
# 55                 97                 55               584.995871
# 759                82                 59               284.294421
#
#      Demand_Supply_Ratio   Demand_class   Supply_class  base_cost  \
# 534             2.391304  Higher_demand   Lower_supply      525.0
# 80              1.909091   Lower_demand  Higher_supply      287.0
# 925             2.703704  Higher_demand   Lower_supply      175.0
# 67              1.900000   Lower_demand  Higher_supply       98.0
# 708             1.250000   Lower_demand  Higher_supply      255.5
# 415             3.481481  Higher_demand   Lower_supply      602.0
# 133             2.361111  Higher_demand   Lower_supply      532.0
# 309             5.250000  Higher_demand   Lower_supply      581.0
# 55              1.763636   Lower_demand  Higher_supply      525.0
# 759             1.389831   Lower_demand  Higher_supply      234.5
#
#      S/D_surge_charge  Surge_charge     New_cost
# 534        255.652174          0.00   780.652174
# 80           0.000000          0.00   287.000000
# 925        104.351852          0.00   279.351852
# 67           0.000000          0.00    98.000000
# 708          0.000000          0.00   255.500000
# 415        522.848148         42.14  1166.988148
# 133        253.438889          0.00   785.438889
# 309        864.237500          0.00  1445.237500
# 55           0.000000         36.75   561.750000
# 759          0.000000          0.00   234.500000

# %% [markdown]
# ## Revenue Before and after

# %%
print("Revenue before applying Dynamic_pricing -->",round(sum(df['Historical_Cost_of_Ride']),2))
print("Revenue after applying Dynamic_pricing-->",round(sum(df['New_cost']),2))
# Out:
# Revenue before applying Dynamic_pricing --> 372502.62
# Revenue after applying Dynamic_pricing--> 552298.01

# %%
diff=sum(df['New_cost'])-sum(df['Historical_Cost_of_Ride'])
print("Diffrenece of Revenue--> ", diff)
print("Revenue Percentage --> ", diff/sum(df['Historical_Cost_of_Ride'])*100)
# Out:
# Diffrenece of Revenue-->  179795.39090132003
# Revenue Percentage -->  48.26687911203326

# %% [markdown]
# ## Conclusion
# * ### Diffrenece of Revenue-->  179795.39
# * ### Revenue Percentage -->  48.26

# %%
filter=df['Demand_Supply_Ratio']>10
df[filter].head(10)
# Out:
#      Number_of_Riders  Number_of_Drivers Location_Category  \
# 49                 67                  6             Rural
# 88                 66                  6             Rural
# 94                 95                  7             Rural
# 153                51                  5             Urban
# 170                76                  7             Urban
# 197                75                  7          Suburban
# 216                88                  5             Urban
# 218                65                  5             Rural
# 232                87                  5             Urban
# 250                97                  7             Urban
#
#     Customer_Loyalty_Status  Number_of_Past_Rides  Average_Ratings  \
# 49                     Gold                    15             3.53
# 88                  Regular                    23             4.20
# 94                     Gold                    40             4.68
# 153                    Gold                     0             4.59
# 170                    Gold                    76             4.35
# 197                    Gold                   100             4.13
# 216                  Silver                    89             3.59
# 218                  Silver                    24             3.54
# 232                  Silver                    59             4.32
# 250                  Silver                    22             3.74
#
#     Time_of_Booking Vehicle_Type  Expected_Ride_Duration  \
# 49            Night      Economy                     123
# 88          Evening      Economy                      45
# 94          Evening      Economy                      95
# 153       Afternoon      Premium                      92
# 170         Morning      Economy                      72
# 197         Morning      Economy                     134
# 216           Night      Economy                      27
# 218           Night      Economy                     119
# 232           Night      Economy                      42
# 250       Afternoon      Premium                     147
#
#      Historical_Cost_of_Ride  Demand_Supply_Ratio   Demand_class  \
# 49                420.623911            11.166667  Higher_demand
# 88                173.157754            11.000000  Higher_demand
# 94                283.466443            13.571429  Higher_demand
# 153               320.857622            10.200000  Higher_demand
# 170               245.893571            10.857143  Higher_demand
# 197               453.376949            10.714286  Higher_demand
# 216                70.203803            17.600000  Higher_demand
# 218               301.403927            13.000000  Higher_demand
# 232               151.359301            17.400000  Higher_demand
# 250               441.746701            13.857143  Higher_demand
#
#      Supply_class  base_cost  rider_driver_ratio  demand_supply_factor  \
# 49   Lower_supply      430.5           11.166667                   6.0
# 88   Lower_supply      157.5           11.000000                   6.0
# 94   Lower_supply      332.5           13.571429                   6.0
# 153  Lower_supply      322.0           10.200000                   6.0
# 170  Lower_supply      252.0           10.857143                   6.0
# 197  Lower_supply      469.0           10.714286                   6.0
# 216  Lower_supply       94.5           17.600000                   6.0
# 218  Lower_supply      416.5           13.000000                   6.0
# 232  Lower_supply      147.0           17.400000                   6.0
# 250  Lower_supply      514.5           13.857143                   6.0
#
#      S/D_surge_charge  Surge_charge   New_cost
# 49             904.05        0.0000  1334.5500
# 88             330.75        0.0000   488.2500
# 94             698.25        0.0000  1030.7500
# 153            676.20        0.0000   998.2000
# 170            529.20        0.0000   781.2000
# 197            984.90        0.0000  1453.9000
# 216            198.45        3.3075   296.2575
# 218            874.65        0.0000  1291.1500
# 232            308.70        5.1450   460.8450
# 250           1080.45        0.0000  1594.9500

# %% [markdown]
# # Data Spliting and Model training

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
x=df[['Demand_Supply_Ratio','Location_Category','Time_of_Booking','Vehicle_Type','Expected_Ride_Duration']] #Train column
y=df['New_cost'] #Target column

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=42)

# %%
X_train
# Out:
#      Demand_Supply_Ratio Location_Category Time_of_Booking Vehicle_Type  \
# 876             1.126437          Suburban       Afternoon      Economy
# 326             1.700000             Urban         Morning      Premium
# 381             9.142857             Rural         Evening      Economy
# 853             1.282051             Urban         Morning      Premium
# 311             2.266667             Urban           Night      Premium
# ..                   ...               ...             ...          ...
# 118             4.043478          Suburban         Evening      Premium
# 334             3.700000             Urban       Afternoon      Economy
# 409             3.142857             Urban         Morning      Premium
# 225             7.571429             Urban           Night      Premium
# 482             3.052632             Urban         Evening      Economy
#
#      Expected_Ride_Duration
# 876                      13
# 326                     158
# 381                      64
# 853                     135
# 311                     134
# ..                      ...
# 118                     125
# 334                      44
# 409                      98
# 225                      10
# 482                      77
#
# [600 rows x 5 columns]

# %%
y_train
# Out:
# 876     45.500000
# 326    553.000000
# 381    694.400000
# 853    472.500000
# 311    501.830000
#           ...
# 118    934.157609
# 334    299.530000
# 409    600.250000
# 225    110.950000
# 482    472.546974
# Name: New_cost, Length: 600, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe = OneHotEncoder()
ohe.fit(x[['Location_Category','Time_of_Booking','Vehicle_Type']])
# Out:
# OneHotEncoder()

# %%
cat=ohe.categories_

# %%
column_trans = make_column_transformer((OneHotEncoder(categories=cat),
                                        ['Location_Category','Time_of_Booking','Vehicle_Type']),
                                        remainder='passthrough')

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# c:\Users\sanoj\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Rural', 'Suburban', 'Urban'], dtype=object),
#                                                                             array(['Afternoon', 'Evening', 'Morning', 'Night'], dtype=object),
#                                                                             array(['Economy', 'Premium'], dtype=object)]),
#                                                   ['Location_Category',
#                                                    'Time_of_Booking',
#                                                    'Vehicle_Type'])])),
#                 ('linearregression', LinearRegression())])

# %%
y_pred=pipe.predict(X_test)
y_pred
# Out:
# array([ 725.49985318,  508.1060693 ,  988.29705641,  393.26549241,
#         318.97656193,  531.98143912,  423.53447011,  119.30788357,
#         693.75509236,  169.27977397,  398.63716732,  210.36750737,
#         193.75497913,  889.54894577,  497.90395848,  500.94705098,
#         880.32441075,  625.99665575,  116.33528796,  451.19424188,
#         614.82082844,  291.05957571,  297.44714832,  465.99765218,
#         291.73430176,  914.86394215,   99.02837815, 1400.26007905,
#         203.81191271, 1115.29983168,  377.38545155,   24.37875791,
#         543.65000518,  111.74637726,  528.84416851,  374.28285041,
#         121.44603573,  297.59227745,  515.23845114,  462.21432185,
#         876.56109658,  815.45941023, 1008.81681601,  949.42843104,
#        1314.13789469,  516.99502246,  422.34182859,  973.97749499,
#         335.00744433,  556.77384055,  450.69908446,   84.22266332,
#         662.45194721,  249.6198604 ,  134.94326023,  451.84849959,
#         422.47184824, 1032.20481351,  875.95829501,  721.90047544,
#         646.89450429,  550.647363  ,  636.85153405,  582.24481034,
#         739.26236395,  489.74335188,  513.95178678,  373.04786679,
#         488.90856772,  236.05905468,  635.79575089,   84.7651164 ,
#         912.73370286,  885.97408323,  390.97058731,  516.20376835,
#         108.54358853, 1034.98128846, 1309.75241291, 1000.05612908,
#        1192.45537501,  686.99607264,  947.69234903,   17.07675902,
#         615.03695592,  767.76501747,  226.60061547,   18.72403359,
#         987.52488447,  819.39929077,  482.38420381,  235.61045161,
#         566.65963983, 1352.44096944,  590.74359767,  820.53028797,
#        1099.33488305,  770.83627473,  586.60304471,  859.41815356,
#         152.95309455,  208.65416968,  378.61126062,  524.71774714,
#         673.52274957,  297.58127213,  864.12245942,  874.18080666,
#         670.67276092,  146.6718127 ,  597.10888122,  437.07211951,
#         883.18164075,  169.23879757,  -55.59241626,  -46.242007  ,
#         281.73224034,  451.62881339,  789.26755813,  207.54361486,
#         310.1307964 ,  171.02250251,  261.16195755,  219.79074875,
#         641.89770266,  -42.8906545 ,  605.0221181 ,  880.03624999,
#         812.62147934,   65.89231429,  690.88437626,  896.0816116 ,
#         942.44552214,  -99.66609388,  525.43005968,  721.83530906,
#         537.48157594,  450.35118661,  975.46121365,  383.55527566,
#         566.83625875,  -26.05342887,  916.51265374,  739.39043769,
#         331.63817703,  597.96464967,  882.68225494,  547.73870968,
#         637.35623451,  217.044136  ,  840.6390455 , 1165.69734982,
#         397.72155442,  558.74029091,  535.64274537,  168.53741741,
#        1078.23583524,  846.51278529,  284.82762865, -114.04212966,
#        1205.18551191,  617.3110958 ,  849.44839191,  471.6990071 ,
#           9.1243251 ,  778.26289592,  838.53740981, 1027.44060231,
#         901.32648605,  846.46909286,  654.46838984,  576.75272121,
#         931.34598303,  595.78299392,  348.17692519,  439.51177291,
#         835.63705089,  332.73458449, -102.31952011,  533.33770098,
#         904.01804631,   24.69253718,  590.32947674, 1060.03620779,
#         478.61282797,  645.79901599,  236.1344639 ,  112.1009901 ,
#         754.05375716,  124.60352389,   10.5819983 , 1052.3933748 ,
#         793.00953416,  959.46523749,  840.67905225,  579.58472559,
#         452.33937408,  584.427814  ,  821.71185302,   96.63419749])

# %% [markdown]
# # Model Evaluation & Check prediction

# %%
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error

# %% [markdown]
# ### Model evaluation on Validation data

# %%
y_val_pred = pipe.predict(X_val)
mape = mean_absolute_percentage_error(y_val,y_val_pred)
print("Error of Linear Regression Model = %.2f"%(mape*100),'%')
print("Accuracy of Linear Regression Model = %.2f"%((1 - mape)*100),'%')
# Out:
# Error of Linear Regression Model = 29.48 %
# Accuracy of Linear Regression Model = 70.52 %

# %%
r2 = r2_score(y_val,y_val_pred)
print("R2 score of Linear Regression = %.2f"%(r2))
# Out:
# R2 score of Linear Regression = 0.81

# %% [markdown]
# ### Model evaluation on Test Data

# %%
y_test_pred = pipe.predict(X_test)
test_mse = mean_squared_error(y_test, y_test_pred)
test_r2 = r2_score(y_test, y_test_pred)
print("Mean square error :", test_mse)
print("R2 score of Linear Regression on test data:", test_r2*100)
# Out:
# Mean square error : 25804.010772131278
# R2 score of Linear Regression on test data: 83.08779931645755

# %%
pipe.predict(pd.DataFrame([['2.0','Urban','Night','Premium','90']],columns=['Demand_Supply_Ratio','Location_Category','Time_of_Booking','Vehicle_Type','Expected_Ride_Duration']))
# Out:
# array([411.07015495])

# %%
results_df = pd.DataFrame(X_test, columns=x.columns)
results_df['Actual'] = y_test
results_df['Predicted'] = y_pred
results_df['Error'] = y_pred-y_test
results_df.to_csv("test_results.csv", index=False)

# %%
df2=pd.read_csv('test_results.csv')
df2.iloc[:,[5,6,7]]
df2.head(10)
# Out:
#    Demand_Supply_Ratio Location_Category Time_of_Booking Vehicle_Type  \
# 0             4.750000             Urban           Night      Economy
# 1             4.611111             Urban         Morning      Economy
# 2             3.142857             Urban         Evening      Premium
# 3             2.230769          Suburban         Evening      Premium
# 4             6.500000          Suburban           Night      Premium
# 5             2.956522          Suburban         Morning      Economy
# 6             5.333333             Urban       Afternoon      Economy
# 7             1.555556          Suburban       Afternoon      Premium
# 8             3.857143             Urban         Morning      Premium
# 9             2.935484             Urban           Night      Economy
#
#    Expected_Ride_Duration       Actual   Predicted       Error
# 0                     114   936.652500  725.499853 -211.152647
# 1                      81   641.812500  508.106069 -133.706431
# 2                     180  1146.600000  988.297056 -158.302944
# 3                      87   325.815000  393.265492   67.450492
# 4                      19   199.167500  318.976562  119.809062
# 5                     105   619.157609  531.981439  -87.176170
# 6                      53   466.841667  423.534470  -43.307197
# 7                      43   150.500000  119.307884  -31.192116
# 8                     120   840.000000  693.755092 -146.244908
# 9                      39   233.745242  169.279774  -64.465468

# %%
df2['Actual'].sum()
# Out:
# 114642.71250925891

# %%
df2['Predicted'].sum()
# Out:
# 110765.39342615806

# %%
diff=df2['Actual'].sum()-df2['Predicted'].sum()
diff
# Out:
# 3877.319083100854

# %%
df2['Error'].sum()
# Out:
# -3877.3190831008574
