# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the dataset

# %%
df= pd.read_csv(r"C:\Users\sanoj\Downloads\dynamic_pricing (1).csv")
df.head()
# Out:
#    Number_of_Riders  Number_of_Drivers Location_Category  \
# 0                90                 45             Urban
# 1                58                 39          Suburban
# 2                42                 31             Rural
# 3                89                 28             Rural
# 4                78                 22             Rural
#
#   Customer_Loyalty_Status  Number_of_Past_Rides  Average_Ratings  \
# 0                  Silver                    13             4.47
# 1                  Silver                    72             4.06
# 2                  Silver                     0             3.99
# 3                 Regular                    67             4.31
# 4                 Regular                    74             3.77
#
#   Time_of_Booking Vehicle_Type  Expected_Ride_Duration  \
# 0           Night      Premium                      90
# 1         Evening      Economy                      43
# 2       Afternoon      Premium                      76
# 3       Afternoon      Premium                     134
# 4       Afternoon      Economy                     149
#
#    Historical_Cost_of_Ride
# 0               284.257273
# 1               173.874753
# 2               329.795469
# 3               470.201232
# 4               579.681422

# %%
df.describe()
# Out:
#        Number_of_Riders  Number_of_Drivers  Number_of_Past_Rides  \
# count       1000.000000        1000.000000           1000.000000
# mean          60.372000          27.076000             50.031000
# std           23.701506          19.068346             29.313774
# min           20.000000           5.000000              0.000000
# 25%           40.000000          11.000000             25.000000
# 50%           60.000000          22.000000             51.000000
# 75%           81.000000          38.000000             75.000000
# max          100.000000          89.000000            100.000000
#
#        Average_Ratings  Expected_Ride_Duration  Historical_Cost_of_Ride
# count      1000.000000              1000.00000              1000.000000
# mean          4.257220                99.58800               372.502623
# std           0.435781                49.16545               187.158756
# min           3.500000                10.00000                25.993449
# 25%           3.870000                59.75000               221.365202
# 50%           4.270000               102.00000               362.019426
# 75%           4.632500               143.00000               510.497504
# max           5.000000               180.00000               836.116419

# %% [markdown]
# # Ratio Based Approach

# %% [markdown]
# ## Calculating Demand_Supply_Ratio and picking demand_supply_threshold = 2.3 arround the mean of Demand_Supply_Ratio
# * ### Higher Demand = when 'Demand_Supply_Ratio' > demand_supply_threshold (2.3) else Low-demand
# * ### Higher supply = when 'Demand_Supply_Ratio' < demand_supply_threshold (2.3) else Low-supply

# %%
df['Demand_Supply_Ratio'] = df['Number_of_Riders'] / df['Number_of_Drivers']
demand_supply_threshold = 2.3

df['Demand_class'] = np.where(df['Demand_Supply_Ratio'] > demand_supply_threshold, "Higher_demand", "Lower_demand")
df['Supply_class'] = np.where(df['Demand_Supply_Ratio'] < demand_supply_threshold, "Higher_supply", "Lower_supply")

df.iloc[:,[0,1,10,11,12]].sample(10)
# Out:
#      Number_of_Riders  Number_of_Drivers  Demand_Supply_Ratio   Demand_class  \
# 463                20                 10             2.000000   Lower_demand
# 82                 81                 23             3.521739  Higher_demand
# 880                62                  8             7.750000  Higher_demand
# 937                56                 37             1.513514   Lower_demand
# 265                77                 30             2.566667  Higher_demand
# 486                42                  7             6.000000  Higher_demand
# 185                47                 17             2.764706  Higher_demand
# 13                 36                 24             1.500000   Lower_demand
# 665                79                 13             6.076923  Higher_demand
# 337                30                  7             4.285714  Higher_demand
#
#       Supply_class
# 463  Higher_supply
# 82    Lower_supply
# 880   Lower_supply
# 937  Higher_supply
# 265   Lower_supply
# 486   Lower_supply
# 185   Lower_supply
# 13   Higher_supply
# 665   Lower_supply
# 337   Lower_supply

# %% [markdown]
# ## calulation Base Price and Surge_charge based on supply demand ratio and demand_supply_factor
# * ### 1. Calculate base historical cost based on expected_Ride_duration
# * ### 2. Calculate rider-to-driver ratio
# * ### 3. Calculate demand-supply factor
# * ### 4. Defining a methode to Calculate supply_demand_surge and Apply the dynamic pricing formula

# %%
constant_rate = 3.5  # Define the base rate per unit of duration, this is arround mean of ratio of ('Historical_Cost_of_Ride'/'Expected_Ride_Duration')
demand_hike = 0.35  # This is how much demand increase the pricing

# Calculate base historical cost based on expected_Ride_duration
df['base_cost'] = df['Expected_Ride_Duration'] * constant_rate

# Calculate rider-to-driver ratio
df['rider_driver_ratio'] = df['Number_of_Riders'] / df['Number_of_Drivers']

# Calculate demand-supply factor
df['demand_supply_factor'] = df['rider_driver_ratio'] - 1
df['demand_supply_factor'] = df['demand_supply_factor'].apply(lambda x: min(x, 6))

# defining a methode to Calculate supply_demand_surge and Apply the dynamic pricing formula
def apply_surge(df):
    SD_surge_charge=0
    if (df['Demand_class']=='Higher_demand') & (df['Supply_class']=='Lower_supply'):
        SD_surge_charge = df['base_cost'] * (demand_hike * df['demand_supply_factor'])
    return SD_surge_charge

df['S/D_surge_charge'] = df.apply(apply_surge,axis=1)
df.head()
# Out:
#    Number_of_Riders  Number_of_Drivers Location_Category  \
# 0                90                 45             Urban
# 1                58                 39          Suburban
# 2                42                 31             Rural
# 3                89                 28             Rural
# 4                78                 22             Rural
#
#   Customer_Loyalty_Status  Number_of_Past_Rides  Average_Ratings  \
# 0                  Silver                    13             4.47
# 1                  Silver                    72             4.06
# 2                  Silver                     0             3.99
# 3                 Regular                    67             4.31
# 4                 Regular                    74             3.77
#
#   Time_of_Booking Vehicle_Type  Expected_Ride_Duration  \
# 0           Night      Premium                      90
# 1         Evening      Economy                      43
# 2       Afternoon      Premium                      76
# 3       Afternoon      Premium                     134
# 4       Afternoon      Economy                     149
#
#    Historical_Cost_of_Ride  Demand_Supply_Ratio   Demand_class   Supply_class  \
# 0               284.257273             2.000000   Lower_demand  Higher_supply
# 1               173.874753             1.487179   Lower_demand  Higher_supply
# 2               329.795469             1.354839   Lower_demand  Higher_supply
# 3               470.201232             3.178571  Higher_demand   Lower_supply
# 4               579.681422             3.545455  Higher_demand   Lower_supply
#
#    base_cost  rider_driver_ratio  demand_supply_factor  S/D_surge_charge
# 0      315.0            2.000000              1.000000          0.000000
# 1      150.5            1.487179              0.487179          0.000000
# 2      266.0            1.354839              0.354839          0.000000
# 3      469.0            3.178571              2.178571        357.612500
# 4      521.5            3.545455              2.545455        464.609091

# %% [markdown]
# ## Conditional Surge based on Vehical_Type and Time_of_booking && Location_Category Condition

# %%
def cal_surge_charge(df):
    surge_charge = 0
    if df['Vehicle_Type'] == 'Premium':
        if (df['Location_Category'] in ('Urban', 'Suburban')) & (df['Time_of_Booking'] in ('Evening', 'Night')):
            surge_charge = df['base_cost'] * 0.05 + df['base_cost'] * 0.02
    else:
        if (df['Location_Category'] in ('Urban', 'Suburban')) & (df['Time_of_Booking'] in ('Evening', 'Night')):
            surge_charge = df['base_cost'] * 0.025 + df['base_cost'] * 0.01
    return surge_charge

df['Surge_charge'] = df.apply(cal_surge_charge, axis=1)

# %%
df.sample(10)
# Out:
#      Number_of_Riders  Number_of_Drivers Location_Category  \
# 57                 95                 25          Suburban
# 494                80                 34          Suburban
# 950                44                 18          Suburban
# 962                95                 49             Rural
# 802                87                 77             Urban
# 906                44                 11             Rural
# 431                85                 25             Urban
# 878                32                 13             Urban
# 330                63                 53             Rural
# 838                88                 48             Urban
#
#     Customer_Loyalty_Status  Number_of_Past_Rides  Average_Ratings  \
# 57                  Regular                    72             4.16
# 494                  Silver                    84             3.80
# 950                    Gold                    88             3.67
# 962                 Regular                    92             4.27
# 802                    Gold                    12             3.56
# 906                  Silver                    31             3.92
# 431                  Silver                    21             4.03
# 878                 Regular                    75             4.56
# 330                    Gold                    33             4.33
# 838                    Gold                    52             4.52
#
#     Time_of_Booking Vehicle_Type  Expected_Ride_Duration  \
# 57          Morning      Premium                     128
# 494           Night      Economy                     174
# 950           Night      Premium                      50
# 962           Night      Premium                      99
# 802           Night      Premium                      11
# 906       Afternoon      Premium                     110
# 431         Morning      Economy                      73
# 878         Evening      Premium                     111
# 330       Afternoon      Economy                     175
# 838           Night      Economy                      92
#
#      Historical_Cost_of_Ride  Demand_Supply_Ratio   Demand_class  \
# 57                413.587084             3.800000  Higher_demand
# 494               561.438522             2.352941  Higher_demand
# 950               199.839744             2.444444  Higher_demand
# 962               332.093616             1.938776   Lower_demand
# 802                97.784506             1.129870   Lower_demand
# 906               339.287073             4.000000  Higher_demand
# 431               323.557686             3.400000  Higher_demand
# 878               333.401167             2.461538  Higher_demand
# 330               489.712524             1.188679   Lower_demand
# 838               230.832586             1.833333   Lower_demand
#
#       Supply_class  base_cost  rider_driver_ratio  demand_supply_factor  \
# 57    Lower_supply      448.0            3.800000              2.800000
# 494   Lower_supply      609.0            2.352941              1.352941
# 950   Lower_supply      175.0            2.444444              1.444444
# 962  Higher_supply      346.5            1.938776              0.938776
# 802  Higher_supply       38.5            1.129870              0.129870
# 906   Lower_supply      385.0            4.000000              3.000000
# 431   Lower_supply      255.5            3.400000              2.400000
# 878   Lower_supply      388.5            2.461538              1.461538
# 330  Higher_supply      612.5            1.188679              0.188679
# 838  Higher_supply      322.0            1.833333              0.833333
#
#      S/D_surge_charge  Surge_charge
# 57         439.040000         0.000
# 494        288.379412        21.315
# 950         88.472222        12.250
# 962          0.000000         0.000
# 802          0.000000         2.695
# 906        404.250000         0.000
# 431        214.620000         0.000
# 878        198.732692        27.195
# 330          0.000000         0.000
# 838          0.000000        11.270

# %% [markdown]
# ## Calculating Total cost

# %%
df['New_cost']= df['base_cost'] + df['S/D_surge_charge'] + df['Surge_charge']
df.iloc[:,[0,1,9,10,11,12,13,16,17,18]].sample(10)
# Out:
#      Number_of_Riders  Number_of_Drivers  Historical_Cost_of_Ride  \
# 650                30                 13               274.680375
# 859                27                  7               555.401937
# 972                58                 10               459.060651
# 341                48                 24                92.031047
# 141                93                 42               674.648504
# 390                27                 15               315.265403
# 156                94                 59               665.729534
# 614                69                 51               470.182714
# 984                34                  7               516.511173
# 193                61                 26               604.273047
#
#      Demand_Supply_Ratio   Demand_class   Supply_class  base_cost  \
# 650             2.307692  Higher_demand   Lower_supply      329.0
# 859             3.857143  Higher_demand   Lower_supply      420.0
# 972             5.800000  Higher_demand   Lower_supply      483.0
# 341             2.000000   Lower_demand  Higher_supply      101.5
# 141             2.214286   Lower_demand  Higher_supply      560.0
# 390             1.800000   Lower_demand  Higher_supply      360.5
# 156             1.593220   Lower_demand  Higher_supply      612.5
# 614             1.352941   Lower_demand  Higher_supply      476.0
# 984             4.857143  Higher_demand   Lower_supply      521.5
# 193             2.346154  Higher_demand   Lower_supply      441.0
#
#      S/D_surge_charge  Surge_charge     New_cost
# 650        150.580769         0.000   479.580769
# 859        420.000000         0.000   840.000000
# 972        811.440000        33.810  1328.250000
# 341          0.000000         0.000   101.500000
# 141          0.000000         0.000   560.000000
# 390          0.000000         0.000   360.500000
# 156          0.000000         0.000   612.500000
# 614          0.000000        33.320   509.320000
# 984        704.025000        36.505  1262.030000
# 193        207.778846         0.000   648.778846

# %% [markdown]
# ## Revenue Before and after

# %%
print("Revenue before applying Dynamic_pricing -->",round(sum(df['Historical_Cost_of_Ride']),2))
print("Revenue after applying Dynamic_pricing-->",round(sum(df['New_cost']),2))
# Out:
# Revenue before applying Dynamic_pricing --> 372502.62
# Revenue after applying Dynamic_pricing--> 552298.01

# %%
diff=sum(df['New_cost'])-sum(df['Historical_Cost_of_Ride'])
print("Diffrenece of Revenue--> ", diff)
print("Revenue Percentage --> ", diff/sum(df['Historical_Cost_of_Ride'])*100)
# Out:
# Diffrenece of Revenue-->  179795.39090132003
# Revenue Percentage -->  48.26687911203326

# %% [markdown]
# ## Conclusion
# * ### Diffrenece of Revenue-->  179795.39
# * ### Revenue Percentage -->  48.26

# %%
filter=df['Demand_Supply_Ratio']>10
df[filter].head(10)
# Out:
#      Number_of_Riders  Number_of_Drivers Location_Category  \
# 49                 67                  6             Rural
# 88                 66                  6             Rural
# 94                 95                  7             Rural
# 153                51                  5             Urban
# 170                76                  7             Urban
# 197                75                  7          Suburban
# 216                88                  5             Urban
# 218                65                  5             Rural
# 232                87                  5             Urban
# 250                97                  7             Urban
#
#     Customer_Loyalty_Status  Number_of_Past_Rides  Average_Ratings  \
# 49                     Gold                    15             3.53
# 88                  Regular                    23             4.20
# 94                     Gold                    40             4.68
# 153                    Gold                     0             4.59
# 170                    Gold                    76             4.35
# 197                    Gold                   100             4.13
# 216                  Silver                    89             3.59
# 218                  Silver                    24             3.54
# 232                  Silver                    59             4.32
# 250                  Silver                    22             3.74
#
#     Time_of_Booking Vehicle_Type  Expected_Ride_Duration  \
# 49            Night      Economy                     123
# 88          Evening      Economy                      45
# 94          Evening      Economy                      95
# 153       Afternoon      Premium                      92
# 170         Morning      Economy                      72
# 197         Morning      Economy                     134
# 216           Night      Economy                      27
# 218           Night      Economy                     119
# 232           Night      Economy                      42
# 250       Afternoon      Premium                     147
#
#      Historical_Cost_of_Ride  Demand_Supply_Ratio   Demand_class  \
# 49                420.623911            11.166667  Higher_demand
# 88                173.157754            11.000000  Higher_demand
# 94                283.466443            13.571429  Higher_demand
# 153               320.857622            10.200000  Higher_demand
# 170               245.893571            10.857143  Higher_demand
# 197               453.376949            10.714286  Higher_demand
# 216                70.203803            17.600000  Higher_demand
# 218               301.403927            13.000000  Higher_demand
# 232               151.359301            17.400000  Higher_demand
# 250               441.746701            13.857143  Higher_demand
#
#      Supply_class  base_cost  rider_driver_ratio  demand_supply_factor  \
# 49   Lower_supply      430.5           11.166667                   6.0
# 88   Lower_supply      157.5           11.000000                   6.0
# 94   Lower_supply      332.5           13.571429                   6.0
# 153  Lower_supply      322.0           10.200000                   6.0
# 170  Lower_supply      252.0           10.857143                   6.0
# 197  Lower_supply      469.0           10.714286                   6.0
# 216  Lower_supply       94.5           17.600000                   6.0
# 218  Lower_supply      416.5           13.000000                   6.0
# 232  Lower_supply      147.0           17.400000                   6.0
# 250  Lower_supply      514.5           13.857143                   6.0
#
#      S/D_surge_charge  Surge_charge   New_cost
# 49             904.05        0.0000  1334.5500
# 88             330.75        0.0000   488.2500
# 94             698.25        0.0000  1030.7500
# 153            676.20        0.0000   998.2000
# 170            529.20        0.0000   781.2000
# 197            984.90        0.0000  1453.9000
# 216            198.45        3.3075   296.2575
# 218            874.65        0.0000  1291.1500
# 232            308.70        5.1450   460.8450
# 250           1080.45        0.0000  1594.9500

# %% [markdown]
# # Data Spliting and Model training

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
x=df[['Demand_Supply_Ratio','Location_Category','Time_of_Booking','Vehicle_Type','Expected_Ride_Duration']] #Train column
y=df['New_cost'] #Target column

# %%
X_train, X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
X_train
# Out:
#      Demand_Supply_Ratio Location_Category Time_of_Booking Vehicle_Type  \
# 29              1.500000          Suburban           Night      Premium
# 535             2.625000             Urban           Night      Premium
# 695             1.312500             Rural         Morning      Economy
# 557             1.521739          Suburban       Afternoon      Economy
# 836             1.296875          Suburban         Evening      Economy
# ..                   ...               ...             ...          ...
# 106             1.571429             Rural       Afternoon      Economy
# 270             6.923077          Suburban       Afternoon      Economy
# 860             2.750000             Rural           Night      Premium
# 435             2.909091          Suburban       Afternoon      Premium
# 102             1.705882             Rural         Morning      Premium
#
#      Expected_Ride_Duration
# 29                      131
# 535                      84
# 695                      70
# 557                     164
# 836                     109
# ..                      ...
# 106                      60
# 270                     126
# 860                     122
# 435                      32
# 102                     131
#
# [800 rows x 5 columns]

# %%
y_train
# Out:
# 29      490.595000
# 535     481.792500
# 695     245.000000
# 557     574.000000
# 836     394.852500
#           ...
# 106     210.000000
# 270    1355.226923
# 860     688.537500
# 435     186.836364
# 102     458.500000
# Name: New_cost, Length: 800, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe = OneHotEncoder()
ohe.fit(x[['Location_Category','Time_of_Booking','Vehicle_Type']])
# Out:
# OneHotEncoder()

# %%
cat=ohe.categories_

# %%
column_trans = make_column_transformer((OneHotEncoder(categories=cat),
                                        ['Location_Category','Time_of_Booking','Vehicle_Type']),
                                        remainder='passthrough',)

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# c:\Users\sanoj\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Rural', 'Suburban', 'Urban'], dtype=object),
#                                                                             array(['Afternoon', 'Evening', 'Morning', 'Night'], dtype=object),
#                                                                             array(['Economy', 'Premium'], dtype=object)]),
#                                                   ['Location_Category',
#                                                    'Time_of_Booking',
#                                                    'Vehicle_Type'])])),
#                 ('linearregression', LinearRegression())])

# %%
y_pred=pipe.predict(X_test)
y_pred
# Out:
# array([ 736.304414  ,  521.0745563 ,  987.22476923,  395.38026094,
#         340.93018233,  540.88829265,  432.81434573,  116.85429583,
#         701.00050633,  176.64210048,  391.51538031,  204.61470217,
#         201.86140097,  889.36034349,  481.93877459,  496.31992514,
#         864.54840188,  629.49522573,  121.85520434,  450.62152732,
#         618.01043887,  304.5906365 ,  301.43493956,  462.25127886,
#         291.42927816,  900.83972581,   97.1450939 , 1429.48030068,
#         195.96851618, 1138.52929135,  378.44006163,   23.05492584,
#         542.64183284,  103.5267465 ,  534.66070383,  374.39173443,
#         115.03933839,  300.39731744,  519.38644318,  458.00646174,
#         881.22069619,  813.25518303, 1021.70330842,  939.77212674,
#        1324.73720154,  501.00737221,  427.18853856,  979.59495554,
#         328.56902124,  560.36647518,  460.45710732,   86.33266403,
#         662.77340968,  248.82181752,  135.17329038,  462.35768115,
#         416.24004459, 1043.35369048,  868.01887533,  713.39286914,
#         648.66313604,  552.96629433,  628.87967059,  570.83513397,
#         744.54265405,  483.54950319,  534.55454174,  383.41120764,
#         483.58362925,  239.93691968,  641.24228287,   89.09357393,
#         916.51357518,  872.18822166,  392.79796873,  509.37823171,
#         116.11928539, 1031.31532188, 1329.63439718,  993.70756231,
#        1229.57653672,  678.59525564,  956.95035374,   25.29732322,
#         608.99464615,  758.24876598,  230.98949892,    9.77650463,
#         987.09328173,  825.04290946,  487.83720251,  239.39406438,
#         572.60364547, 1385.12791748,  590.01032545,  810.61112779,
#        1100.99379208,  797.31328554,  584.38341396,  846.84789165,
#         146.90289277,  209.78974285,  376.66896515,  520.74012881,
#         667.09191901,  294.58095404,  859.82355629,  868.06032374,
#         671.11230144,  136.6703348 ,  590.85841454,  436.07239002,
#         876.19668498,  173.69058512,  -59.05454012,  -39.06040285,
#         299.48516779,  461.73285982,  782.80371939,  208.90073009,
#         317.43522218,  165.17588523,  278.12945295,  226.73407048,
#         649.11394389,  -44.08444672,  611.7500812 ,  869.5024427 ,
#         808.08237217,   62.38079691,  680.77130919,  911.56623916,
#         939.37796021,  -96.66505129,  518.46435343,  719.80918105,
#         539.45436761,  440.15084572,  973.67778223,  386.57802514,
#         568.96552387,  -34.29979435,  913.12055224,  744.68859346,
#         344.29523801,  594.20792549,  880.32316467,  538.67402386,
#         635.07614696,  206.31864558,  828.59656959, 1175.40525661,
#         398.17636016,  560.75681484,  525.47507291,  165.91959174,
#        1081.52635475,  842.91132975,  273.52469186, -110.62949004,
#        1220.16628057,  624.65370084,  864.14795118,  461.61776836,
#          15.62057247,  774.88498645,  820.69440544, 1014.88529093,
#         903.88731723,  846.2162642 ,  653.43882782,  562.09228611,
#         933.36811981,  602.30022411,  357.51048604,  432.09898852,
#         830.44702717,  320.61133966, -101.74476655,  554.84354394,
#         906.71538933,   16.35085777,  588.83522329, 1068.58531715,
#         489.11473278,  636.09362859,  237.97093372,  117.45852698,
#         740.79011763,  139.98128666,   14.89283672, 1055.98379379,
#         792.35703552,  963.35680647,  841.79515833,  583.29117986,
#         451.17561809,  575.55271065,  807.8896756 ,   97.7224655 ])

# %% [markdown]
# # Model Evaluation & Check prediction

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
mape = mean_absolute_percentage_error(y_test,y_pred)
print("Error of Linear Regression Model = %.2f"%(mape*100),'%')
print("Accuracy of Linear Regression Model = %.2f"%((1 - mape)*100),'%')
# Out:
# Error of Linear Regression Model = 30.70 %
# Accuracy of Linear Regression Model = 69.30 %

# %%
r2 = r2_score(y_test,y_pred)
print("R2 score of Linear Regression = %.2f"%(r2))
# Out:
# R2 score of Linear Regression = 0.84

# %%
pipe.predict(pd.DataFrame([['2.0','Urban','Night','Premium','90']],columns=['Demand_Supply_Ratio','Location_Category','Time_of_Booking','Vehicle_Type','Expected_Ride_Duration']))
# Out:
# array([411.59386835])
